# %%
#Jawaban No1

Nama = 'Angga Dwi Prasetyo'
Nim = '0110124213'
Kelas = 'SI03'
Notelp = '089514572790'
Alamat = 'Pondok gede Bekasi Jawa Barat'

print('Nama', Nama, 'Nim', Nim, 'Kelas', Kelas, 'Notelp', Notelp, 'Alamat', Alamat)
print('=========================')

#Jawaban No2

Nama = 'Muhammad Syuja Yazid Beckham Putra Manumayasa'
Nim = '0110124092'
Kelas = 'SI03'
Notelp = '083894845514'
Alamat = 'Bogor Barat Jasinga'

print('Nama', ':', Nama, 'Nim', Nim, 'Kelas', Kelas, 'Notelp', Notelp, 'Alamat', Alamat)
print('=========================')

#Jawaban No3

Tinggi = 160
Berat = (Tinggi -100) - ((Tinggi -100)*0.15)

print('Berapa berat badan ideal untuk tinggi 160? (160 -100) - ((160 -100)*0.15)')
print('Berat badan Ideal untuk tinggi 160 adalah', Berat, 'kg')
print('=========================')

#Jawaban No4

Celcius = 25
Fahrenheit = (Celcius *9/5) + 32

print('Celcius = 25')
print('berapa Fahrenheit? Fahrenheit = (Celcius *9/5) + 32')
print('suhu dalam Celcius:', Celcius, 'C')
print('suhu dalam Fahrenheit:', Fahrenheit, 'F')
print('=========================')
#Jawaban No5


Diameter = 28
Tinggi = 50
JariJari = 14
Rumus = 22/7
Luas = 2*22/7*14 + (50+28)
Keliling = 2*22/7*14

print('hasil luas tabung adalah', Luas*Rumus*JariJari+Diameter+Tinggi, 'cm²')
print('hasil keliling tabung adalah', Keliling, 'cm²')
print('=========================')
# Out:
# Nama Angga Dwi Prasetyo Nim 0110124213 Kelas SI03 Notelp 089514572790 Alamat Pondok gede Bekasi Jawa Barat
# ...
# Nama : Muhammad Syuja Yazid Beckham Putra Manumayasa Nim 0110124092 Kelas SI03 Notelp 083894845514 Alamat Bogor Barat Jasinga
# ...
# Berapa berat badan ideal untuk tinggi 160? (160 -100) - ((160 -100)*0.15)
# Berat badan Ideal untuk tinggi 160 adalah 51.0 kg
# ...
# Celcius = 25
# berapa Fahrenheit? Fahrenheit = (Celcius *9/5) + 32
# suhu dalam Celcius: 25 C
# suhu dalam Fahrenheit: 77.0 F
# ...
# hasil luas tabung adalah 7381.999999999999 cm²
# hasil keliling tabung adalah 88.0 cm²
# ...
